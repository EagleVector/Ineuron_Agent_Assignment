# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
attendance = pd.read_csv('AgentLogingReport.csv', parse_dates = ['Date'])

# %%
attendance.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane 2022-07-30   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya 2022-07-30   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta 2022-07-30   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi 2022-07-30   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh 2022-07-30   14:03:15    15:11:52  01:08:36

# %%
attendance.shape
# Out:
# (1000, 6)

# %%
attendance = attendance.set_index('SL No')

# %%
attendance['Day'] = attendance['Date'].dt.day

# %%
attendance['Month'] = attendance['Date'].dt.month

# %%
attendance['Week'] = attendance['Date'].dt.isocalendar().week

# %%
attendance['Duration'] = pd.to_timedelta(attendance['Duration'])

# %%
attendance['Login Time'] = pd.to_timedelta(attendance['Login Time'])

# %%
attendance['Logout Time'] = pd.to_timedelta(attendance['Logout Time'])

# %%
attendance.head()
# Out:
#                     Agent       Date      Login Time     Logout Time  \
# SL No
# 1      Shivananda Sonwane 2022-07-30 0 days 15:35:29 0 days 17:39:39
# 2          Khushboo Priya 2022-07-30 0 days 15:06:59 0 days 15:07:16
# 3           Nandani Gupta 2022-07-30 0 days 15:04:24 0 days 17:31:07
# 4         Hrisikesh Neogi 2022-07-30 0 days 14:34:29 0 days 15:19:35
# 5                  Mukesh 2022-07-30 0 days 14:03:15 0 days 15:11:52
#
#              Duration  Day  Month  Week
# SL No
# 1     0 days 02:04:10   30      7    30
# 2     0 days 00:00:17   30      7    30
# 3     0 days 02:26:42   30      7    30
# 4     0 days 00:45:06   30      7    30
# 5     0 days 01:08:36   30      7    30

# %%
performance = pd.read_csv('AgentPerformance.csv', parse_dates = ['Date'])

# %%
performance.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
# 2      3 2022-07-30     Ameya Jain           14               0:00:30
# 3      4 2022-07-30  Mahesh Sarade           14               0:01:04
# 4      5 2022-07-30         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# 2                 0:11:36            4.55              11
# 3                 0:15:46            4.71               7
# 4                 0:16:33            3.67               6

# %%
performance.shape
# Out:
# (2160, 8)

# %%
performance = performance.set_index('SL No')

# %%
performance['Average Response Time'] = pd.to_timedelta(performance['Average Response Time'])

# %%
performance['Average Resolution Time'] = pd.to_timedelta(performance['Average Resolution Time'])

# %%
performance.head()
# Out:
#             Date     Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30   Prerna Singh           11       0 days 00:00:38
# 2     2022-07-30  Nandani Gupta           11       0 days 00:01:15
# 3     2022-07-30     Ameya Jain           14       0 days 00:00:30
# 4     2022-07-30  Mahesh Sarade           14       0 days 00:01:04
# 5     2022-07-30         Swati            14       0 days 00:01:11
#
#       Average Resolution Time  Average Rating  Total Feedback
# SL No
# 1             0 days 00:04:20            4.11               9
# 2             0 days 00:28:25            3.14               7
# 3             0 days 00:11:36            4.55              11
# 4             0 days 00:15:46            4.71               7
# 5             0 days 00:16:33            3.67               6

# %%
performance['Day'] = performance['Date'].dt.day

# %%
performance['Month'] = performance['Date'].dt.month

# %%
performance['Week'] = performance['Date'].dt.isocalendar().week

# %%
performance.head()
# Out:
#             Date     Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30   Prerna Singh           11       0 days 00:00:38
# 2     2022-07-30  Nandani Gupta           11       0 days 00:01:15
# 3     2022-07-30     Ameya Jain           14       0 days 00:00:30
# 4     2022-07-30  Mahesh Sarade           14       0 days 00:01:04
# 5     2022-07-30         Swati            14       0 days 00:01:11
#
#       Average Resolution Time  Average Rating  Total Feedback  Day  Month  \
# SL No
# 1             0 days 00:04:20            4.11               9   30      7
# 2             0 days 00:28:25            3.14               7   30      7
# 3             0 days 00:11:36            4.55              11   30      7
# 4             0 days 00:15:46            4.71               7   30      7
# 5             0 days 00:16:33            3.67               6   30      7
#
#        Week
# SL No
# 1        30
# 2        30
# 3        30
# 4        30
# 5        30

# %% [markdown]
# 1. Find out there avarage rating on weekly basis keep this in mind that they take two days of leave.

# %%
performance.groupby(['Agent Name', 'Week'])['Average Rating'].mean()
# Out:
# Agent Name              Week
# Abhishek                26      0.000000
#                         27      0.000000
#                         28      0.000000
#                         29      0.000000
#                         30      0.000000
# Aditya                  26      0.000000
#                         27      0.000000
#                         28      0.000000
#                         29      0.000000
#                         30      0.000000
# Aditya Shinde           26      2.566667
#                         27      3.225714
#                         28      3.390000
#                         29      0.000000
#                         30      0.000000
# Aditya_iot              26      0.000000
#                         27      1.232857
#                         28      2.928571
#                         29      3.114286
#                         30      3.238333
# Amersh                  26      0.000000
#                         27      0.000000
# ...

# %% [markdown]
# 2. Total working days for each agent.

# %%
df = attendance.groupby('Agent')['Day'].nunique()
df
# Out:
# Agent
# Aditya Shinde              1
# Aditya_iot                 8
# Amersh                     2
# Ameya Jain                 7
# Ankitjha                   2
# Anurag Tiwari             10
# Aravind                    7
# Ayushi Mishra              9
# Bharath                    8
# Boktiar Ahmed Bappy        9
# Chaitra K Hiremath         7
# Deepranjan Gupta          10
# Dibyanshu                  9
# Harikrishnan Shaji         9
# Hrisikesh Neogi            9
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            11
# Jawala Prakash             9
# Jaydeep Dixit              7
# Khushboo Priya             8
# Madhulika G                8
# Mahesh Sarade              8
# Maitry                     5
# Manjunatha A               7
# Mithun S                   8
# Mukesh                     2
# Muskan Garg                6
# Nandani Gupta              9
# Nishtha Jain               8
# Nitin M                    1
# Prabir Kumar Satapathy     7
# ...

# %% [markdown]
# 3. Total query that you have taken.

# %%
performance.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             277
# Aditya_iot                231
# Amersh                      0
# Ameya Jain                322
# Anirudh                    81
# Ankit Sharma                0
# Ankitjha                    5
# Anurag Tiwari               4
# Aravind                   366
# Ashad Nasim                18
# Ashish                      0
# Ayushi Mishra             514
# Bharath                   369
# Boktiar Ahmed Bappy       452
# Chaitra K Hiremath         64
# Deepranjan Gupta          493
# Dibyanshu                   1
# Harikrishnan Shaji        381
# Hitesh Choudhary            1
# Hrisikesh Neogi           578
# Hyder Abbas                 0
# Ineuron Intelligence        0
# Ishawant Kumar            338
# Jawala Prakash            439
# Jayant Kumar              127
# Jaydeep Dixit             512
# Khushboo Priya            446
# Madhulika G               469
# ...

# %% [markdown]
# 4. Total Feedback that you have received.

# %%
performance.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# Ameya Jain                228
# Anirudh                    39
# Ankit Sharma                0
# Ankitjha                    3
# Anurag Tiwari               3
# Aravind                   233
# Ashad Nasim                 9
# Ashish                      0
# Ayushi Mishra             329
# Bharath                   247
# Boktiar Ahmed Bappy       311
# Chaitra K Hiremath         37
# Deepranjan Gupta          312
# Dibyanshu                   0
# Harikrishnan Shaji        231
# Hitesh Choudhary            0
# Hrisikesh Neogi           367
# Hyder Abbas                 0
# Ineuron Intelligence        0
# Ishawant Kumar            202
# Jawala Prakash            250
# Jayant Kumar               70
# Jaydeep Dixit             305
# Khushboo Priya            289
# Madhulika G               281
# ...

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
rt = performance.groupby('Agent Name')['Average Rating'].mean()

# %%
rtn = pd.DataFrame(rt)

# %%
rtn
# Out:
#                         Average Rating
# Agent Name
# Abhishek                      0.000000
# Aditya                        0.000000
# Aditya Shinde                 1.800333
# Aditya_iot                    2.345333
# Amersh                        0.000000
# Ameya Jain                    2.219667
# Anirudh                       0.645000
# Ankit Sharma                  0.000000
# Ankitjha                      0.266667
# Anurag Tiwari                 0.183333
# Aravind                       2.181333
# Ashad Nasim                   0.166667
# Ashish                        0.000000
# Ayushi Mishra                 3.482000
# Bharath                       2.983667
# Boktiar Ahmed Bappy           3.568000
# Chaitra K Hiremath            0.864667
# Deepranjan Gupta              2.886667
# Dibyanshu                     0.000000
# Harikrishnan Shaji            2.639667
# Hitesh Choudhary              0.000000
# Hrisikesh Neogi               3.136333
# Hyder Abbas                   0.000000
# ...

# %% [markdown]
# 5. An agent name who have average rating between 3.5 to 4.6

# %%
rtn[(rtn['Average Rating'] > 3.5) & (rtn['Average Rating'] < 4.6)]
# Out:
#                      Average Rating
# Agent Name
# Boktiar Ahmed Bappy        3.568000
# Ishawant Kumar             3.543333
# Khushboo Priya             3.703667
# Manjunatha A               3.594667
# Shivananda Sonwane         4.232667

# %% [markdown]
# 6. Agent name who have rating lesss then 3.5

# %%
rtn[rtn['Average Rating'] < 3.5]
# Out:
#                         Average Rating
# Agent Name
# Abhishek                      0.000000
# Aditya                        0.000000
# Aditya Shinde                 1.800333
# Aditya_iot                    2.345333
# Amersh                        0.000000
# Ameya Jain                    2.219667
# Anirudh                       0.645000
# Ankit Sharma                  0.000000
# Ankitjha                      0.266667
# Anurag Tiwari                 0.183333
# Aravind                       2.181333
# Ashad Nasim                   0.166667
# Ashish                        0.000000
# Ayushi Mishra                 3.482000
# Bharath                       2.983667
# Chaitra K Hiremath            0.864667
# Deepranjan Gupta              2.886667
# Dibyanshu                     0.000000
# Harikrishnan Shaji            2.639667
# Hitesh Choudhary              0.000000
# Hrisikesh Neogi               3.136333
# Hyder Abbas                   0.000000
# Ineuron Intelligence          0.000000
# ...

# %% [markdown]
#  7. Agent name who have rating more then 4.5

# %%
rtn[rtn['Average Rating'] > 4.5]
# Out:
# Empty DataFrame
# Columns: [Average Rating]
# Index: []

# %% [markdown]
# 8 . In How many feedabacks agents have received more then 4.5 average.

# %%
df = performance[['Agent Name', 'Total Feedback', 'Average Rating']]
df
# Out:
#                    Agent Name  Total Feedback  Average Rating
# SL No
# 1                Prerna Singh               9            4.11
# 2               Nandani Gupta               7            3.14
# 3                  Ameya Jain              11            4.55
# 4               Mahesh Sarade               7            4.71
# 5                      Swati                6            3.67
# 6                     Mukesh                8            4.62
# 7             Saikumarreddy N              12            5.00
# 8               Sanjeev Kumar               6            5.00
# 9              Shubham Sharma               8            4.38
# 10               Nishtha Jain              16            4.12
# 11               Manjunatha A               5            3.60
# 12             Khushboo Priya              14            4.43
# 13              Suraj S Bilgi              11            4.36
# 14         Harikrishnan Shaji               7            4.57
# ...

# %%
df[df['Average Rating'] > 4.5]
# Out:
#                    Agent Name  Total Feedback  Average Rating
# SL No
# 3                  Ameya Jain              11            4.55
# 4               Mahesh Sarade               7            4.71
# 6                     Mukesh                8            4.62
# 7             Saikumarreddy N              12            5.00
# 8               Sanjeev Kumar               6            5.00
# 14         Harikrishnan Shaji               7            4.57
# 17          Sowmiya Sivakumar              16            4.75
# 68        Boktiar Ahmed Bappy               4            4.75
# 69         Shivananda Sonwane               1            5.00
# 70             Ishawant Kumar               3            4.67
# 71           Deepranjan Gupta               5            4.80
# 73         Shivananda Sonwane               9            4.67
# 76                Muskan Garg               4            5.00
# 78                Aditya_iot               10            4.60
# ...

# %%
df['Total Feedback'].sum()
# Out:
# 9259

# %% [markdown]
# 9. Average weekly response time for each agent.

# %%
performance.groupby(['Agent Name', 'Week'])['Average Response Time'].mean()
# Out:
# Agent Name              Week
# Abhishek                26               0 days 00:00:00
#                         27               0 days 00:00:00
#                         28               0 days 00:00:00
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya                  26               0 days 00:00:00
#                         27               0 days 00:00:00
#                         28               0 days 00:00:00
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya Shinde           26     0 days 00:00:55.333333333
#                         27     0 days 00:00:47.285714285
#                         28     0 days 00:00:56.428571428
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya_iot              26               0 days 00:00:00
# ...

# %% [markdown]
# 10. Average weekely resolution time for each agents.

# %%
performance.groupby(['Agent Name', 'Week'])['Average Resolution Time'].mean()
# Out:
# Agent Name              Week
# Abhishek                26               0 days 00:00:00
#                         27               0 days 00:00:00
#                         28               0 days 00:00:00
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya                  26               0 days 00:00:00
#                         27               0 days 00:00:00
#                         28               0 days 00:00:00
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya Shinde           26               0 days 00:15:27
#                         27     0 days 00:15:03.857142857
#                         28     0 days 00:22:38.714285714
#                         29               0 days 00:00:00
#                         30               0 days 00:00:00
# Aditya_iot              26               0 days 00:00:00
# ...

# %% [markdown]
# 11. List of all agents name.

# %%
performance['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
# ...

# %% [markdown]
# 12. Percentage of chat on which they have received a feedback.

# %%
performance['TCFB_Diff'] = performance['Total Chats'] - performance['Total Feedback']

# %%
performance
# Out:
#             Date              Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30            Prerna Singh           11       0 days 00:00:38
# 2     2022-07-30           Nandani Gupta           11       0 days 00:01:15
# 3     2022-07-